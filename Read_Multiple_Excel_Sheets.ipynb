# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Edit Pandas Setting To Show All Columns

# %%
pd.set_option("display.max_columns", 30)

# %% [markdown]
# ### Read Data

# %%
# Read All Sheets In The Excel File as Dictionary
excel_sheet = pd.read_excel("supply_data.xlsx", sheet_name = None)
print(type(excel_sheet))
excel_sheet.keys()
# Out:
# <class 'dict'>
# dict_keys(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %% [markdown]
# ### Concat All Sheets Together

# %%
# Create Empty df
df = pd.DataFrame()

# %%
# Looping on all Sheets To Concat it with the df
for k, _ in excel_sheet.items():
    df = pd.concat([df, excel_sheet[k]], ignore_index=True)

# %%
df.shape
# Out:
# (61, 29)

# %% [markdown]
# ### Replace Space From Columns With _

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns
# Out:
# Index(['Month', 'Day', 'Load', 'Tonnage', 'Customer_Type', 'Destination',
#        'Rate', 'Truck', 'Insurance', 'Fuel', 'Diesel_Exhaust_Fluid', 'Advance',
#        'Warehouse', 'Repairs', 'Tolls', 'Fundings', 'Driver_Name', 'Odometer',
#        'Miles', 'Rate_Per_Miles', 'Extra_Stops', 'Extra_Pay',
#        'Costs_Driver_Paid', 'Total_Expenses', 'First_condition_type',
#        'Shipment_cost_sub-items', 'ERE_Stage', 'Basic_freight',
#        'Final_Amount'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Month  Day  Load  Tonnage       Customer_Type       Destination  Rate  \
# 0   Jan    1  Wood     11.0  Retaining Customer          Nunavut.  5556
# 1   Jan    3  Wood     21.3  Retaining Customer  British Columbia  5556
# 2   Jan   13  Wood     22.0  Retaining Customer          Manitoba  5556
# 3   Feb    4  Sand     14.5  Retaining Customer  British Columbia  4567
# 4   Feb    5  Sand     18.0  Retaining Customer          Manitoba  4567
# 5   Feb    6  Sand     19.0  Retaining Customer     New Brunswick  4567
# 6   Feb   14  Sand     20.0  Retaining Customer           Nunavut  4567
# 7   Mar    2  Iron     21.0  Retaining Customer          Manitoba  3458
# 8   Mar    3  Iron     22.0        New Customer  British Columbia  3458
# 9   Mar    7  Sand     22.7        New Customer          Manitoba  3458
#
#                    Truck  Insurance  Fuel  Diesel_Exhaust_Fluid  Advance  \
# 0  Freightliner Sprinter        132   400                    50      250
# ...
